# %%
import numpy as np
import pandas as pd

URL_DATA = 'https://storage.googleapis.com/dosm-public-pricecatcher/lookup_premise.parquet'
df_premise_code = pd.read_parquet(URL_DATA)
if 'date' in df_premise_code.columns: df_premise_code['date'] = pd.to_datetime(df_premise_code['date'])


URL_DATA = 'https://storage.googleapis.com/dosm-public-pricecatcher/lookup_item.parquet'
df_item_code = pd.read_parquet(URL_DATA)
if 'date' in df_item_code.columns: df_item_code['date'] = pd.to_datetime(df_item_code['date'])

# %%
import numpy as np
import pandas as pd

#!pip install pandas fastparquet

URL_DATA = 'https://storage.googleapis.com/dosm-public-pricecatcher/pricecatcher_2023-09.parquet'

df = pd.read_parquet(URL_DATA)
if 'date' in df.columns: df['date'] = pd.to_datetime(df['date'])
df.tail()
# Out:
#               date  premise_code  item_code  price
# 2454096 2022-01-31         20715       1978    4.2
# 2454097 2022-01-31         20715       2001   25.5
# 2454098 2022-01-31         20715       2008   18.2
# 2454099 2022-01-31         20715       2009   23.9
# 2454100 2022-01-31         20715       2010   23.9

# %%
def merge_data(df):

    tempdf = df.copy() #must make a copy . doing tempdf=df7 is just reassigning

    print(tempdf.head())
    #
    p =tempdf.pop('premise_code').map(df_premise_code.set_index('premise_code')["premise_type"])
    p.name = 'premise_type'


    tempdf = df.copy() #must make a copy . doing tempdf=df7 is just reassigning
    q =tempdf.pop('premise_code').map(df_premise_code.set_index('premise_code')["premise"])
    q.name = 'premise'

    tempdf = df.copy() #must make a copy . doing tempdf=df7 is just reassigning
    s =tempdf.pop('premise_code').map(df_premise_code.set_index('premise_code')["state"])
    s.name = 'state'

    tempdf = df.copy() #must make a copy . doing tempdf=df7 is just reassigning
    t = tempdf.pop('premise_code').map(df_premise_code.set_index('premise_code')['district'])
    t.name = "district"

    tempdf = df.copy() #must make a copy . doing tempdf=df7 is just reassigning
    u = tempdf.pop('item_code').map(df_item_code.set_index('item_code')['item'])
    u.name = "item"

    tempdf = df.copy() #must make a copy . doing tempdf=df7 is just reassigning
    v = tempdf.pop('item_code').map(df_item_code.set_index('item_code')['unit'])
    v.name = "unit"

    tempdf = df.copy() #must make a copy . doing tempdf=df7 is just reassigning
    w = tempdf.pop('item_code').map(df_item_code.set_index('item_code')['item_category'])
    w.name = "item_category"

    
    tempdf = df.copy() #must make a copy . doing tempdf=df7 is just reassigning
    w2 = tempdf.pop('item_code').map(df_item_code.set_index('item_code')['item_group'])
    w2.name = "item_group"

    #print('S:\n',s) 
    #print('T:\n',t)

    df_merged = pd.concat([df,p,q,s,t,u,v,w,w2],axis=1)
    return df_merged

# %%
df_master = merge_data(df)
# Out:
#         date  premise_code  item_code  price
# 0 2022-01-01             2          1    9.1
# 1 2022-01-01             2          9   36.0
# 2 2022-01-01             2         14   24.0
# 3 2022-01-01             2         16    4.3
# 4 2022-01-01             2         18    4.5

# %%
df_master.head()
# Out:
#         date  premise_code  item_code  price  premise_type           premise  \
# 0 2022-01-01             2          1    9.1  Pasar Basah   PASAR BESAR IPOH
# 1 2022-01-01             2          9   36.0  Pasar Basah   PASAR BESAR IPOH
# 2 2022-01-01             2         14   24.0  Pasar Basah   PASAR BESAR IPOH
# 3 2022-01-01             2         16    4.3  Pasar Basah   PASAR BESAR IPOH
# 4 2022-01-01             2         18    4.5  Pasar Basah   PASAR BESAR IPOH
#
#    state district                                               item unit  \
# 0  Perak    Kinta                             AYAM BERSIH - STANDARD  1kg
# 1  Perak    Kinta  DAGING KAMBING BEBIRI IMPORT BERTULANG (MUTTON...  1kg
# 2  Perak    Kinta          DAGING KERBAU IMPORT (INDIA) * (TOP SIDE)  1kg
# 3  Perak    Kinta                                        BETIK BIASA  1kg
# 4  Perak    Kinta                                    PISANG BERANGAN  1kg
#
#   item_category      item_group
# 0          AYAM  BARANGAN SEGAR
# 1        DAGING  BARANGAN SEGAR
# 2        DAGING  BARANGAN SEGAR
# 3   BUAH-BUAHAN  BARANGAN SEGAR
# 4   BUAH-BUAHAN  BARANGAN SEGAR

# %%
df_master.item_group.unique()
# Out:
# array(['BARANGAN SEGAR', 'BARANGAN KERING', 'BARANGAN BERBUNGKUS',
#        'MINUMAN', 'PRODUK KEBERSIHAN', 'SUSU DAN BARANGAN BAYI',
#        'MAKANAN SIAP MASAK', 'BARANGAN KEDAI SERBANEKA'], dtype=object)

# %%
df_master[df_master['item_group']=='BARANGAN SEGAR'].item_category.unique()
# Out:
# array(['AYAM', 'DAGING', 'BUAH-BUAHAN', 'BAHAN LAUT', 'IKAN DARAT',
#        'SAYUR-SAYURAN', 'KELAPA', 'TELUR', 'MEE/KUETIAU',
#        'TAUHU DAN TEMPE'], dtype=object)

# %%
df_master[df_master['item']=='DAGING LEMBUTEMPATAN']
# Out:
# Empty DataFrame
# Columns: [date, premise_code, item_code, price, premise_type, premise, state, district, item, unit, item_category, item_group]
# Index: []

# %%
df_ayam = df_master[df_master['item_code']==1]
df_ayam.head()
# Out:
#            date  premise_code  item_code  price              premise_type  \
# 0    2022-01-01             2          1   9.10              Pasar Basah
# 932  2022-01-01            16          1   8.90  Pasar Raya / Supermarket
# 1152 2022-01-01           115          1   8.30  Pasar Raya / Supermarket
# 1386 2022-01-01           136          1   8.99  Pasar Raya / Supermarket
# 1611 2022-01-01           141          1   8.60  Pasar Raya / Supermarket
#
#                                  premise              state  district  \
# 0                       PASAR BESAR IPOH              Perak     Kinta
# 932   PASARAYA K-CERIA (KANGAR) SDN. BHD             Perlis    Kangar
# 1152              TAMPIN SHOPPING CENTRE    Negeri Sembilan    Tampin
# 1386            THE STORE ( PUDU PLAZA )  W.P. Kuala Lumpur    Cheras
# 1611                         HUDA GROCER    Negeri Sembilan  Seremban
#
#                         item unit item_category      item_group
# 0     AYAM BERSIH - STANDARD  1kg          AYAM  BARANGAN SEGAR
# 932   AYAM BERSIH - STANDARD  1kg          AYAM  BARANGAN SEGAR
# 1152  AYAM BERSIH - STANDARD  1kg          AYAM  BARANGAN SEGAR
# 1386  AYAM BERSIH - STANDARD  1kg          AYAM  BARANGAN SEGAR
# 1611  AYAM BERSIH - STANDARD  1kg          AYAM  BARANGAN SEGAR

# %%
df_ayam.tail()
# Out:
#               date  premise_code  item_code  price              premise_type  \
# 2420197 2022-01-31         17871       1431   36.0              Pasar Basah
# 2420294 2022-01-31         17872       1431   36.0              Pasar Basah
# 2425585 2022-01-31         17987       1431   58.0               Hypermarket
# 2432776 2022-01-31         18144       1431   41.9  Pasar Raya / Supermarket
# 2445988 2022-01-31         18503       1431   58.0  Pasar Raya / Supermarket
#
#                                  premise    state     district  \
# 2420197              PASAR AWAM MAHARANI    Johor         Muar
# 2420294               PASAR AWAM TANGKAK    Johor       Ledang
# 2425585    MYDIN HYPERMARKET VISTA TUNKU  Sarawak      Kuching
# 2432776  NSK TRADE CITY (PANDAN) SDN BHD    Johor  Johor Bahru
# 2445988        LEPAPA SUPERMARKET MATANG  Sarawak      Kuching
#
#                                                       item unit item_category  \
# 2420197  DAGING LEMBU TEMPATAN (BAHAGIAN 1 DAGING PAHA ...  1kg        DAGING
# 2420294  DAGING LEMBU TEMPATAN (BAHAGIAN 1 DAGING PAHA ...  1kg        DAGING
# 2425585  DAGING LEMBU TEMPATAN (BAHAGIAN 1 DAGING PAHA ...  1kg        DAGING
# 2432776  DAGING LEMBU TEMPATAN (BAHAGIAN 1 DAGING PAHA ...  1kg        DAGING
# 2445988  DAGING LEMBU TEMPATAN (BAHAGIAN 1 DAGING PAHA ...  1kg        DAGING
#
#              item_group
# 2420197  BARANGAN SEGAR
# 2420294  BARANGAN SEGAR
# 2425585  BARANGAN SEGAR
# 2432776  BARANGAN SEGAR
# 2445988  BARANGAN SEGAR

# %%
df_ayam[['price']].mean()
# Out:
# price    8.868708
# dtype: float64
